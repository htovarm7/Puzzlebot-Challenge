# %% [markdown]
# # Train Traffic Sign YOLOv8 Model

# %%
import torch
from ultralytics import YOLO

print(f"torch={torch.__version__}  CUDA={torch.cuda.is_available()}")
# Out:
# torch=2.12.0+cu130  CUDA=True

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="NDhWAQO9NCJ3gOFQQ2s5")
project = rf.workspace("larc-hbgqy").project("traffic-signals-1t7zq")
version = project.version(3)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# The 'strict' parameter is no longer needed on Python 3+. This will raise an error in urllib3 v3.0.
# loading Roboflow project...

# %%
model = YOLO("yolov8n.pt")  

results = model.train(
    data="Traffic-Signals-3/data.yaml",
    epochs=200,
    imgsz=256,            
    batch=16,
    patience=20,
    fliplr=0.0,
    flipud=0.0,
    degrees=0.0,
    shear=0.0,
    project="runs",
    name="train",
)
# Out:
# Ultralytics 8.4.61 🚀 Python-3.10.12 torch-2.12.0+cu130 CUDA:0 (NVIDIA GeForce RTX 3060, 11901MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=Traffic-Signals-3/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=200, erasing=0.4, exist_ok=False, fliplr=0.0, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=256, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=train-2, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=20, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=runs, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/home/lalo/Desktop/Puzzlebot-Challenge/training/runs/detect/runs/train-2, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=5
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    752287  ultralytics.nn.modules.head.Detect           [5, 16, None, [64, 128, 256]]
# Model summary: 130 layers, 3,011,823 parameters, 3,011,807 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1951.6±1059.9 MB/s, size: 17.2 KB)
# train: Scanning /home/lalo/Desktop/Puzzlebot-Challenge/training/Traffic-Signals-3/train/labels.cache... 1053 images, 243 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1053/1053 339.7Mit/s 0.0s
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 807, len(boxes) = 810. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 392.9±171.0 MB/s, size: 6.0 KB)
# val: Scanning /home/lalo/Desktop/Puzzlebot-Challenge/training/Traffic-Signals-3/valid/labels.cache... 101 images, 19 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 101/101 5.7Mit/s 0.0s
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 81, len(boxes) = 82. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001111, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Plotting labels to /home/lalo/Desktop/Puzzlebot-Challenge/training/runs/detect/runs/train-2/labels.jpg...
# Image sizes 256 train, 256 val
# Using 8 dataloader workers
# Logging results to /home/lalo/Desktop/Puzzlebot-Challenge/training/runs/detect/runs/train-2
# Starting training for 200 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/200     0.383G     0.6678       2.56      1.077         13        256: 100% ━━━━━━━━━━━━ 66/66 17.1it/s 3.9s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 6.1it/s 0.7s0.2s
#                    all        101         82      0.521      0.547      0.487      0.451
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/200     0.426G     0.6015      1.397      1.023         13        256: 100% ━━━━━━━━━━━━ 66/66 26.6it/s 2.5s0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 21.3it/s 0.2s.4s
#                    all        101         82       0.81      0.795      0.852      0.755
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/200     0.426G     0.6044      1.193       1.02         13        256: 100% ━━━━━━━━━━━━ 66/66 27.7it/s 2.4s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 21.0it/s 0.2s.4s
#                    all        101         82      0.877      0.883      0.947      0.804
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/200     0.426G     0.5725      1.043      1.001         13        256: 100% ━━━━━━━━━━━━ 66/66 28.5it/s 2.3s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 22.0it/s 0.2s.4s
#                    all        101         82      0.825      0.906      0.889      0.776
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/200     0.426G     0.5529     0.9413      1.006         13        256: 100% ━━━━━━━━━━━━ 66/66 28.4it/s 2.3s0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 21.8it/s 0.2s.4s
#                    all        101         82      0.914      0.942      0.946      0.876
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/200     0.426G     0.5554     0.9365      1.001         13        256: 100% ━━━━━━━━━━━━ 66/66 28.5it/s 2.3s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 21.6it/s 0.2s.4s
#                    all        101         82      0.831      0.787      0.876      0.808
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/200     0.426G     0.5324     0.8922     0.9966         13        256: 100% ━━━━━━━━━━━━ 66/66 28.8it/s 2.3s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 22.1it/s 0.2s.4s
#                    all        101         82      0.837      0.875       0.96        0.9
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/200     0.426G     0.4973     0.8385     0.9828         13        256: 100% ━━━━━━━━━━━━ 66/66 28.2it/s 2.3s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 20.9it/s 0.2s.4s
#                    all        101         82      0.891      0.892       0.96      0.915
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/200     0.426G     0.4969     0.7863     0.9882         13        256: 100% ━━━━━━━━━━━━ 66/66 27.5it/s 2.4s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 21.1it/s 0.2s.4s
#                    all        101         82      0.925      0.929      0.955      0.893
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/200     0.426G     0.4547     0.7084     0.9619         13        256: 100% ━━━━━━━━━━━━ 66/66 27.0it/s 2.4s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 21.2it/s 0.2s.4s
#                    all        101         82      0.911      0.956      0.958      0.906
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/200     0.426G     0.4632     0.7104     0.9798         13        256: 100% ━━━━━━━━━━━━ 66/66 27.5it/s 2.4s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 21.2it/s 0.2s.4s
#                    all        101         82       0.92      0.907       0.96      0.922
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/200     0.426G     0.4413     0.6905     0.9579         13        256: 100% ━━━━━━━━━━━━ 66/66 27.6it/s 2.4s0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 21.7it/s 0.2s.4s
#                    all        101         82      0.948      0.936      0.957      0.905
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/200     0.426G     0.4444     0.6552     0.9618         13        256: 100% ━━━━━━━━━━━━ 66/66 27.8it/s 2.4s0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 21.9it/s 0.2s.4s
#                    all        101         82      0.935      0.922      0.959      0.907
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/200     0.426G      0.436      0.647     0.9653         13        256: 100% ━━━━━━━━━━━━ 66/66 27.6it/s 2.4s0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 22.1it/s 0.2s.4s
#                    all        101         82      0.925      0.936      0.958      0.917
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/200     0.426G     0.4166     0.6307     0.9485         13        256: 100% ━━━━━━━━━━━━ 66/66 28.0it/s 2.4s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 21.8it/s 0.2s.4s
#                    all        101         82      0.929      0.921      0.965      0.918
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/200     0.426G     0.4107     0.5963     0.9529         13        256: 100% ━━━━━━━━━━━━ 66/66 27.4it/s 2.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 22.1it/s 0.2s.4s
#                    all        101         82      0.937      0.972      0.977      0.941
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/200     0.426G     0.4174     0.5955     0.9556         13        256: 100% ━━━━━━━━━━━━ 66/66 27.1it/s 2.4s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 22.7it/s 0.2s.4s
#                    all        101         82        0.9      0.939       0.97      0.919
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/200     0.426G     0.4081     0.5781     0.9431         13        256: 100% ━━━━━━━━━━━━ 66/66 26.8it/s 2.5s0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 21.3it/s 0.2s.4s
#                    all        101         82      0.954      0.957      0.969      0.913
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/200     0.426G     0.4292      0.588     0.9589         13        256: 100% ━━━━━━━━━━━━ 66/66 24.5it/s 2.7s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 24.4it/s 0.2s.2s
#                    all        101         82      0.918      0.929      0.962      0.913
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/200     0.426G     0.4116     0.5558     0.9541         13        256: 100% ━━━━━━━━━━━━ 66/66 26.7it/s 2.5s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 21.7it/s 0.2s.4s
#                    all        101         82      0.925      0.957      0.955      0.924
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/200     0.426G     0.4017     0.5414     0.9541         13        256: 100% ━━━━━━━━━━━━ 66/66 26.9it/s 2.5s0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 21.6it/s 0.2s.4s
#                    all        101         82      0.865      0.939       0.95      0.893
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/200     0.426G     0.3989     0.5351     0.9501         13        256: 100% ━━━━━━━━━━━━ 66/66 26.1it/s 2.5s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 14.7it/s 0.3s.5s
#                    all        101         82      0.958      0.972      0.975      0.909
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/200     0.426G     0.3821     0.5183     0.9352         13        256: 100% ━━━━━━━━━━━━ 66/66 26.9it/s 2.5s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 22.2it/s 0.2s.4s
#                    all        101         82      0.951      0.961      0.964      0.928
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/200     0.426G     0.3919     0.5298     0.9482         13        256: 100% ━━━━━━━━━━━━ 66/66 27.0it/s 2.4s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 22.1it/s 0.2s.4s
#                    all        101         82      0.936      0.972      0.975      0.914
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/200     0.426G     0.3902     0.5236     0.9463         13        256: 100% ━━━━━━━━━━━━ 66/66 27.5it/s 2.4s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 22.1it/s 0.2s.4s
#                    all        101         82      0.903      0.986      0.939      0.892
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/200     0.426G     0.3793     0.5195     0.9403         13        256: 100% ━━━━━━━━━━━━ 66/66 27.8it/s 2.4s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 20.8it/s 0.2s.4s
#                    all        101         82      0.901      0.969      0.957      0.924
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/200     0.426G     0.3768     0.4971     0.9375         13        256: 100% ━━━━━━━━━━━━ 66/66 27.6it/s 2.4s0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 21.9it/s 0.2s.4s
#                    all        101         82       0.91      0.982       0.96      0.915
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      28/200     0.426G     0.3876     0.5115     0.9427         13        256: 100% ━━━━━━━━━━━━ 66/66 27.9it/s 2.4s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 22.7it/s 0.2s.3s
#                    all        101         82      0.915      0.977      0.975      0.924
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      29/200     0.426G      0.359     0.4787      0.936         13        256: 100% ━━━━━━━━━━━━ 66/66 28.5it/s 2.3s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 23.5it/s 0.2s.3s
#                    all        101         82      0.898       0.94      0.956      0.921
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      30/200     0.426G     0.3607     0.4862     0.9432         13        256: 100% ━━━━━━━━━━━━ 66/66 28.7it/s 2.3s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 22.8it/s 0.2s.4s
#                    all        101         82      0.919      0.985      0.952      0.933
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      31/200     0.426G      0.372     0.4756       0.93         13        256: 100% ━━━━━━━━━━━━ 66/66 28.9it/s 2.3s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 23.1it/s 0.2s.4s
#                    all        101         82      0.919      0.971      0.955      0.929
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      32/200     0.426G     0.3527     0.4649      0.931         13        256: 100% ━━━━━━━━━━━━ 66/66 29.0it/s 2.3s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 22.5it/s 0.2s.4s
#                    all        101         82      0.946      0.965       0.97      0.928
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      33/200     0.426G     0.3614      0.461     0.9306         13        256: 100% ━━━━━━━━━━━━ 66/66 28.3it/s 2.3s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 22.8it/s 0.2s.4s
#                    all        101         82      0.877      0.983      0.967      0.918
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      34/200     0.426G     0.3468     0.4438     0.9238         13        256: 100% ━━━━━━━━━━━━ 66/66 27.9it/s 2.4s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 22.8it/s 0.2s.3s
#                    all        101         82      0.937      0.955      0.968      0.952
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      35/200     0.426G     0.3564     0.4412     0.9319         13        256: 100% ━━━━━━━━━━━━ 66/66 24.2it/s 2.7s0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 22.7it/s 0.2s.4s
#                    all        101         82      0.945      0.963      0.977      0.942
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      36/200     0.426G     0.3454     0.4484     0.9195         13        256: 100% ━━━━━━━━━━━━ 66/66 28.4it/s 2.3s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 22.8it/s 0.2s.3s
#                    all        101         82      0.912      0.966      0.975      0.957
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      37/200     0.426G     0.3497     0.4542     0.9241         13        256: 100% ━━━━━━━━━━━━ 66/66 27.7it/s 2.4s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 22.9it/s 0.2s.3s
#                    all        101         82      0.953      0.952      0.972      0.936
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      38/200     0.426G     0.3359     0.4332      0.915         13        256: 100% ━━━━━━━━━━━━ 66/66 27.8it/s 2.4s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 23.1it/s 0.2s.3s
#                    all        101         82      0.874       0.98      0.959      0.936
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      39/200     0.426G     0.3383     0.4266     0.9195         13        256: 100% ━━━━━━━━━━━━ 66/66 27.7it/s 2.4s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 23.0it/s 0.2s.3s
#                    all        101         82      0.908      0.954      0.941      0.902
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      40/200     0.426G     0.3491     0.4283      0.936         13        256: 100% ━━━━━━━━━━━━ 66/66 28.2it/s 2.3s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 23.2it/s 0.2s.3s
#                    all        101         82       0.92       0.96       0.97      0.928
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      41/200     0.426G     0.3342      0.434     0.9302         13        256: 100% ━━━━━━━━━━━━ 66/66 28.4it/s 2.3s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 22.9it/s 0.2s.3s
#                    all        101         82      0.903      0.947       0.97      0.942
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      42/200     0.426G     0.3355     0.4172     0.9216         13        256: 100% ━━━━━━━━━━━━ 66/66 28.3it/s 2.3s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 23.1it/s 0.2s.3s
#                    all        101         82       0.93      0.972      0.974      0.945
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      43/200     0.426G      0.328     0.4207     0.9246         13        256: 100% ━━━━━━━━━━━━ 66/66 28.3it/s 2.3s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 22.9it/s 0.2s.3s
#                    all        101         82      0.935      0.966      0.973      0.943
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      44/200     0.426G     0.3275      0.415     0.9278         13        256: 100% ━━━━━━━━━━━━ 66/66 28.7it/s 2.3s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 22.5it/s 0.2s.4s
#                    all        101         82      0.906      0.968      0.964       0.94
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      45/200     0.426G     0.3069     0.4004     0.9123         13        256: 100% ━━━━━━━━━━━━ 66/66 23.9it/s 2.8s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 22.9it/s 0.2s.3s
#                    all        101         82      0.926      0.946      0.944      0.929
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      46/200     0.426G     0.3161     0.3933     0.9117         13        256: 100% ━━━━━━━━━━━━ 66/66 27.1it/s 2.4s0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 22.5it/s 0.2s.4s
#                    all        101         82      0.913      0.946      0.952       0.94
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      47/200     0.426G     0.3166     0.3828     0.9128         13        256: 100% ━━━━━━━━━━━━ 66/66 27.8it/s 2.4s0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 23.3it/s 0.2s.3s
#                    all        101         82      0.938      0.937       0.97      0.942
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      48/200     0.426G     0.3326     0.4067     0.9256         13        256: 100% ━━━━━━━━━━━━ 66/66 27.9it/s 2.4s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 22.7it/s 0.2s.3s
#                    all        101         82      0.949      0.924      0.968       0.94
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      49/200     0.426G     0.3391     0.3967     0.9293         13        256: 100% ━━━━━━━━━━━━ 66/66 28.0it/s 2.4s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 23.3it/s 0.2s.3s
#                    all        101         82       0.95      0.954      0.968      0.929
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      50/200     0.426G     0.3254     0.4041     0.9169         13        256: 100% ━━━━━━━━━━━━ 66/66 28.2it/s 2.3s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 23.0it/s 0.2s.3s
#                    all        101         82      0.949      0.963      0.974      0.947
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      51/200     0.426G     0.3149     0.3813      0.917         13        256: 100% ━━━━━━━━━━━━ 66/66 28.1it/s 2.3s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 22.9it/s 0.2s.3s
#                    all        101         82      0.931      0.962      0.967      0.945
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      52/200     0.426G     0.3101     0.3838     0.9219         13        256: 100% ━━━━━━━━━━━━ 66/66 28.1it/s 2.3s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 23.5it/s 0.2s.3s
#                    all        101         82      0.942      0.912      0.959      0.937
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      53/200     0.426G     0.3176      0.414      0.924         13        256: 100% ━━━━━━━━━━━━ 66/66 28.0it/s 2.4s0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 22.0it/s 0.2s.4s
#                    all        101         82      0.937      0.969      0.966      0.936
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      54/200     0.426G     0.3087     0.3817     0.9163         13        256: 100% ━━━━━━━━━━━━ 66/66 24.5it/s 2.7s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 23.3it/s 0.2s.3s
#                    all        101         82      0.927      0.939      0.962      0.942
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      55/200     0.426G     0.3159     0.3801     0.9222         13        256: 100% ━━━━━━━━━━━━ 66/66 28.5it/s 2.3s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 22.9it/s 0.2s.3s
#                    all        101         82       0.92      0.969       0.97      0.953
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      56/200     0.426G     0.2939     0.3797     0.9036         13        256: 100% ━━━━━━━━━━━━ 66/66 27.8it/s 2.4s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 23.6it/s 0.2s.3s
#                    all        101         82      0.926      0.927      0.935      0.918
# EarlyStopping: Training stopped early as no improvement observed in last 20 epochs. Best results observed at epoch 36, best model saved as best.pt.
# To update EarlyStopping(patience=20) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 56 epochs completed in 0.043 hours.
# Optimizer stripped from /home/lalo/Desktop/Puzzlebot-Challenge/training/runs/detect/runs/train-2/weights/last.pt, 6.2MB
# Optimizer stripped from /home/lalo/Desktop/Puzzlebot-Challenge/training/runs/detect/runs/train-2/weights/best.pt, 6.2MB
#
# Validating /home/lalo/Desktop/Puzzlebot-Challenge/training/runs/detect/runs/train-2/weights/best.pt...
# Ultralytics 8.4.61 🚀 Python-3.10.12 torch-2.12.0+cu130 CUDA:0 (NVIDIA GeForce RTX 3060, 11901MiB)
# Model summary (fused): 73 layers, 3,006,623 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 9.5it/s 0.4s0.2s
#                    all        101         82      0.892      0.979      0.974      0.957
#            Go-Straight         12         12          1      0.995      0.995      0.986
#                   Stop         29         29      0.939          1      0.995      0.989
#              Turn-Left         14         14      0.877      0.929      0.905      0.905
#             Turn-Right         12         12      0.709          1      0.989      0.989
#                Workers         15         15      0.936       0.97      0.987      0.914
# Speed: 0.1ms preprocess, 0.6ms inference, 0.0ms loss, 1.8ms postprocess per image
# Results saved to /home/lalo/Desktop/Puzzlebot-Challenge/training/runs/detect/runs/train-2

# %%
metrics = model.val()
print(metrics.box.map)     # mAP50-95
print(metrics.box.map50)   # mAP50
print(metrics.box.maps)    # per-class mAP50-95
