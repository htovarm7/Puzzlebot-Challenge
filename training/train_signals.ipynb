# %% [markdown]
# # Train Traffic Sign YOLOv8 Model

# %%
import torch
from ultralytics import YOLO

print(f"torch={torch.__version__}  CUDA={torch.cuda.is_available()}")
# Out:
# torch=2.9.1+cu128  CUDA=True

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="NDhWAQO9NCJ3gOFQQ2s5")
project = rf.workspace("larc-hbgqy").project("traffic-signals-1t7zq")
version = project.version(5)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in Traffic-Signals-5 to yolov8:: 100%|██████████| 190132/190132 [00:08<00:00, 22184.90it/s]
# Extracting Dataset Version Zip to Traffic-Signals-5 in yolov8:: 100%|██████████| 4505/4505 [00:00<00:00, 13574.02it/s]

# %%
model = YOLO("yolov8n.pt")  

results = model.train(
    data="Traffic-Signals-5/data.yaml",
    epochs=300,
    imgsz=256,            
    batch=16,
    patience=20,
    fliplr=0.0,
    flipud=0.0,
    degrees=0.0,
    shear=0.0,
    project="runs",
    name="train",
)
# Out:
# New https://pypi.org/project/ultralytics/8.4.64 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.244 🚀 Python-3.10.12 torch-2.9.1+cu128 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 7806MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=Traffic-Signals-5/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=300, erasing=0.4, exist_ok=False, fliplr=0.0, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=256, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train3, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=20, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=runs, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/home/hector/Desktop/Puzzlebot-Challenge/training/runs/train3, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=9
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    753067  ultralytics.nn.modules.head.Detect           [9, [64, 128, 256]]
# Model summary: 129 layers, 3,012,603 parameters, 3,012,587 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt': 100% ━━━━━━━━━━━━ 5.4MB 11.9MB/s 0.4s.4s<0.1s0s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 235.0±140.2 MB/s, size: 79.2 KB)
# train: Scanning /home/hector/Desktop/Puzzlebot-Challenge/training/Traffic-Signals-5/train/labels... 1968 images, 357 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1968/1968 1.3Kit/s 1.5s0.0s
# train: /home/hector/Desktop/Puzzlebot-Challenge/training/Traffic-Signals-5/train/images/semaforov2_mov-0010_jpg.rf.55a580f3973eb43febf8059fbf7bbd8c.jpg: 1 duplicate labels removed
# train: /home/hector/Desktop/Puzzlebot-Challenge/training/Traffic-Signals-5/train/images/semaforov2_mov-0010_jpg.rf.6fd8751b591a3552cf39f4f802bebb8c.jpg: 1 duplicate labels removed
# train: /home/hector/Desktop/Puzzlebot-Challenge/training/Traffic-Signals-5/train/images/semaforov2_mov-0010_jpg.rf.8ebc67637e71224351b6e79ae2e2a167.jpg: 1 duplicate labels removed
# train: /home/hector/Desktop/Puzzlebot-Challenge/training/Traffic-Signals-5/train/images/semaforov2_mov-0096_jpg.rf.b41a3631b9726671d21c82e0e308995f.jpg: 1 duplicate labels removed
# train: /home/hector/Desktop/Puzzlebot-Challenge/training/Traffic-Signals-5/train/images/semaforov2_mov-0096_jpg.rf.d72f713e2685eae3d2af9ce39747aeba.jpg: 1 duplicate labels removed
# train: /home/hector/Desktop/Puzzlebot-Challenge/training/Traffic-Signals-5/train/images/semaforov2_mov-0096_jpg.rf.f1047a17ed4cf54b97e3158e5e89d3a2.jpg: 1 duplicate labels removed
# train: /home/hector/Desktop/Puzzlebot-Challenge/training/Traffic-Signals-5/train/images/semaforov2_mov-0144_jpg.rf.c0b53c92a9abbab47b3def1125abb7b1.jpg: 1 duplicate labels removed
# train: /home/hector/Desktop/Puzzlebot-Challenge/training/Traffic-Signals-5/train/images/semaforov2_mov-0144_jpg.rf.c1739b0ac015a2a7fc91d22e61e74b41.jpg: 1 duplicate labels removed
# train: /home/hector/Desktop/Puzzlebot-Challenge/training/Traffic-Signals-5/train/images/semaforov2_mov-0144_jpg.rf.ec206d851da72bc6e24c073ab9cac774.jpg: 1 duplicate labels removed
# train: New cache created: /home/hector/Desktop/Puzzlebot-Challenge/training/Traffic-Signals-5/train/labels.cache
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 1614, len(boxes) = 1617. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 124.0±65.0 MB/s, size: 27.9 KB)
# val: Scanning /home/hector/Desktop/Puzzlebot-Challenge/training/Traffic-Signals-5/valid/labels... 188 images, 32 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 188/188 2.7Kit/s 0.1s
# val: /home/hector/Desktop/Puzzlebot-Challenge/training/Traffic-Signals-5/valid/images/semaforov2_mov-0011_jpg.rf.aafc24cafa4948413d4e188fd47204b7.jpg: 1 duplicate labels removed
# val: /home/hector/Desktop/Puzzlebot-Challenge/training/Traffic-Signals-5/valid/images/semaforov2_mov-0012_jpg.rf.955fd7432c79f5f3e0a5eefaa869b595.jpg: 1 duplicate labels removed
# val: New cache created: /home/hector/Desktop/Puzzlebot-Challenge/training/Traffic-Signals-5/valid/labels.cache
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 155, len(boxes) = 156. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# Plotting labels to /home/hector/Desktop/Puzzlebot-Challenge/training/runs/train3/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000769, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 256 train, 256 val
# Using 8 dataloader workers
# Logging results to /home/hector/Desktop/Puzzlebot-Challenge/training/runs/train3
# Starting training for 300 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/300     0.393G     0.7178      2.905       1.05         25        256: 100% ━━━━━━━━━━━━ 123/123 24.7it/s 5.0s0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 11.6it/s 0.5s.1s
#                    all        188        156       0.48      0.705      0.653      0.619
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/300     0.453G     0.6063      1.385     0.9772         34        256: 100% ━━━━━━━━━━━━ 123/123 41.3it/s 3.0s0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 30.8it/s 0.2s.2s
#                    all        188        156      0.806      0.778      0.862        0.8
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/300     0.471G     0.5857      1.138     0.9649         28        256: 100% ━━━━━━━━━━━━ 123/123 42.1it/s 2.9s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 30.4it/s 0.2s.3s
#                    all        188        156      0.909      0.953      0.971      0.896
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/300     0.488G     0.5612     0.9755     0.9572         27        256: 100% ━━━━━━━━━━━━ 123/123 42.2it/s 2.9s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 31.4it/s 0.2s.2s
#                    all        188        156      0.932      0.953      0.979      0.911
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/300     0.506G     0.5397     0.9223      0.948         28        256: 100% ━━━━━━━━━━━━ 123/123 41.6it/s 3.0s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 31.3it/s 0.2s.2s
#                    all        188        156      0.923      0.946      0.964      0.907
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/300     0.521G     0.5109     0.8174     0.9391         24        256: 100% ━━━━━━━━━━━━ 123/123 41.9it/s 2.9s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 32.3it/s 0.2s.2s
#                    all        188        156      0.928      0.992      0.969      0.913
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/300     0.539G     0.4994     0.7758      0.948         26        256: 100% ━━━━━━━━━━━━ 123/123 42.3it/s 2.9s0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 33.2it/s 0.2s.2s
#                    all        188        156      0.936       0.97      0.971      0.932
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/300     0.557G     0.4782     0.7205     0.9344         24        256: 100% ━━━━━━━━━━━━ 123/123 41.9it/s 2.9s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 31.3it/s 0.2s.3s
#                    all        188        156       0.93      0.966      0.976      0.929
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/300     0.572G      0.463     0.6929     0.9267         33        256: 100% ━━━━━━━━━━━━ 123/123 41.8it/s 2.9s0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 32.2it/s 0.2s.2s
#                    all        188        156      0.965       0.95       0.97      0.925
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/300      0.59G     0.4612     0.6793     0.9266         26        256: 100% ━━━━━━━━━━━━ 123/123 41.8it/s 2.9s0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 31.4it/s 0.2s.2s
#                    all        188        156      0.919      0.971      0.981      0.952
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/300     0.607G     0.4615     0.6496     0.9312         25        256: 100% ━━━━━━━━━━━━ 123/123 41.5it/s 3.0s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 31.2it/s 0.2s.2s
#                    all        188        156      0.948      0.971      0.979      0.938
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/300     0.625G     0.4484     0.6266     0.9268         30        256: 100% ━━━━━━━━━━━━ 123/123 41.0it/s 3.0s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 31.2it/s 0.2s.2s
#                    all        188        156      0.951      0.955      0.969      0.933
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/300     0.641G     0.4419     0.6001      0.922         31        256: 100% ━━━━━━━━━━━━ 123/123 41.0it/s 3.0s0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 31.0it/s 0.2s.2s
#                    all        188        156      0.945      0.975      0.974       0.94
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/300     0.658G     0.4358     0.5923     0.9149         28        256: 100% ━━━━━━━━━━━━ 123/123 41.5it/s 3.0s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 32.6it/s 0.2s.2s
#                    all        188        156      0.943      0.956      0.971      0.944
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/300     0.676G     0.4208     0.5636     0.9197         32        256: 100% ━━━━━━━━━━━━ 123/123 41.8it/s 2.9s0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 33.3it/s 0.2s.2s
#                    all        188        156      0.915      0.964      0.971      0.942
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/300     0.691G     0.4158     0.5427     0.9193         28        256: 100% ━━━━━━━━━━━━ 123/123 41.2it/s 3.0s0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 33.6it/s 0.2s0.2s
#                    all        188        156       0.95      0.984      0.976       0.95
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/300     0.709G     0.4117      0.546     0.9153         22        256: 100% ━━━━━━━━━━━━ 123/123 40.6it/s 3.0s0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 32.9it/s 0.2s.2s
#                    all        188        156      0.948      0.977      0.968      0.944
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/300     0.727G     0.4152     0.5255     0.9155         30        256: 100% ━━━━━━━━━━━━ 123/123 40.2it/s 3.1s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 32.2it/s 0.2s.2s
#                    all        188        156      0.921       0.95      0.967      0.943
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/300     0.744G      0.401     0.4947     0.9107         32        256: 100% ━━━━━━━━━━━━ 123/123 41.0it/s 3.0s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 32.5it/s 0.2s.2s
#                    all        188        156      0.935      0.976      0.974      0.948
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/300      0.76G     0.3935     0.5121     0.9065         23        256: 100% ━━━━━━━━━━━━ 123/123 40.2it/s 3.1s0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 32.6it/s 0.2s.2s
#                    all        188        156      0.938      0.975      0.974      0.943
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/300     0.777G     0.3846     0.4675      0.902         24        256: 100% ━━━━━━━━━━━━ 123/123 40.7it/s 3.0s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 32.2it/s 0.2s.2s
#                    all        188        156      0.948      0.955      0.973      0.948
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/300     0.795G     0.3798     0.4723     0.9117         26        256: 100% ━━━━━━━━━━━━ 123/123 40.5it/s 3.0s0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 32.2it/s 0.2s.2s
#                    all        188        156      0.942       0.98      0.972      0.946
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/300     0.811G     0.3875     0.4926     0.9057         32        256: 100% ━━━━━━━━━━━━ 123/123 40.8it/s 3.0s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 30.9it/s 0.2s.2s
#                    all        188        156      0.925      0.971      0.981      0.951
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/300     0.828G     0.3718     0.4848     0.9049         30        256: 100% ━━━━━━━━━━━━ 123/123 39.6it/s 3.1s0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 31.5it/s 0.2s.2s
#                    all        188        156      0.929      0.974      0.974      0.948
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/300     0.846G      0.377     0.4688     0.9058         27        256: 100% ━━━━━━━━━━━━ 123/123 40.2it/s 3.1s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 30.8it/s 0.2s.2s
#                    all        188        156      0.939      0.976      0.981      0.959
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/300     0.863G     0.3653     0.4643     0.9048         31        256: 100% ━━━━━━━━━━━━ 123/123 40.7it/s 3.0s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 32.2it/s 0.2s.2s
#                    all        188        156      0.945      0.966      0.965      0.933
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/300     0.879G     0.3782     0.4586     0.9029         24        256: 100% ━━━━━━━━━━━━ 123/123 40.6it/s 3.0s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 31.9it/s 0.2s.2s
#                    all        188        156      0.915      0.978      0.969      0.948
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      28/300     0.896G     0.3715     0.4637      0.903         33        256: 100% ━━━━━━━━━━━━ 123/123 40.2it/s 3.1s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 31.9it/s 0.2s.2s
#                    all        188        156      0.945      0.969      0.977      0.959
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      29/300     0.914G     0.3609     0.4647     0.8984         25        256: 100% ━━━━━━━━━━━━ 123/123 40.1it/s 3.1s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 31.9it/s 0.2s.2s
#                    all        188        156      0.942      0.978      0.979      0.954
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      30/300      0.93G     0.3647     0.4556     0.9023         38        256: 100% ━━━━━━━━━━━━ 123/123 40.9it/s 3.0s0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 28.8it/s 0.2s.2s
#                    all        188        156       0.96      0.982      0.985      0.957
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      31/300     0.947G      0.363     0.4439     0.8989         28        256: 100% ━━━━━━━━━━━━ 123/123 40.0it/s 3.1s0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 30.8it/s 0.2s.2s
#                    all        188        156       0.93      0.988      0.979       0.96
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      32/300     0.965G       0.35     0.4317     0.8926         18        256: 100% ━━━━━━━━━━━━ 123/123 39.7it/s 3.1s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 32.2it/s 0.2s.2s
#                    all        188        156      0.952      0.984      0.981      0.961
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      33/300     0.982G     0.3521     0.4358     0.8951         22        256: 100% ━━━━━━━━━━━━ 123/123 39.5it/s 3.1s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 30.8it/s 0.2s.2s
#                    all        188        156      0.957      0.967      0.968      0.953
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      34/300     0.998G     0.3459     0.4266       0.89         32        256: 100% ━━━━━━━━━━━━ 123/123 40.1it/s 3.1s0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 31.7it/s 0.2s.2s
#                    all        188        156      0.959       0.98       0.97      0.959
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      35/300      1.02G     0.3488     0.4088     0.8939         18        256: 100% ━━━━━━━━━━━━ 123/123 40.4it/s 3.0s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 31.7it/s 0.2s.2s
#                    all        188        156      0.972      0.959      0.977      0.955
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      36/300      1.03G     0.3489     0.4224      0.902         30        256: 100% ━━━━━━━━━━━━ 123/123 39.1it/s 3.1s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 32.5it/s 0.2s.2s
#                    all        188        156      0.953      0.981      0.976      0.969
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      37/300      1.05G     0.3428     0.4179     0.8911         27        256: 100% ━━━━━━━━━━━━ 123/123 39.6it/s 3.1s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 32.0it/s 0.2s.2s
#                    all        188        156      0.947      0.978      0.973      0.956
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      38/300      1.07G     0.3444     0.3981      0.895         27        256: 100% ━━━━━━━━━━━━ 123/123 39.9it/s 3.1s0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 30.2it/s 0.2s.4s
#                    all        188        156      0.961      0.972       0.98      0.956
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      39/300      1.08G     0.3426     0.4086     0.8927         31        256: 100% ━━━━━━━━━━━━ 123/123 39.5it/s 3.1s0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 32.0it/s 0.2s.2s
#                    all        188        156       0.95      0.974      0.973      0.948
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      40/300       1.1G      0.338     0.3918     0.8884         35        256: 100% ━━━━━━━━━━━━ 123/123 39.8it/s 3.1s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 31.3it/s 0.2s.3s
#                    all        188        156      0.963      0.967      0.976      0.962
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      41/300      1.12G     0.3283      0.387     0.8895         27        256: 100% ━━━━━━━━━━━━ 123/123 39.7it/s 3.1s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 30.7it/s 0.2s.3s
#                    all        188        156      0.953      0.985      0.979      0.958
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      42/300      1.13G     0.3335     0.3959     0.8896         34        256: 100% ━━━━━━━━━━━━ 123/123 40.0it/s 3.1s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 32.6it/s 0.2s.2s
#                    all        188        156      0.943      0.969      0.973      0.945
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      43/300      1.15G      0.324     0.3752     0.8881         25        256: 100% ━━━━━━━━━━━━ 123/123 39.2it/s 3.1s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 30.0it/s 0.2s.3s
#                    all        188        156      0.951      0.983      0.972      0.952
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      44/300      1.17G     0.3271     0.3729     0.8887         31        256: 100% ━━━━━━━━━━━━ 123/123 39.5it/s 3.1s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 31.2it/s 0.2s.2s
#                    all        188        156      0.956       0.97      0.974      0.962
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      45/300      1.19G     0.3297     0.3852     0.8906         29        256: 100% ━━━━━━━━━━━━ 123/123 39.0it/s 3.2s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 32.0it/s 0.2s.2s
#                    all        188        156       0.95      0.977      0.973       0.96
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      46/300       1.2G     0.3241     0.3823     0.8889         28        256: 100% ━━━━━━━━━━━━ 123/123 39.7it/s 3.1s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 30.6it/s 0.2s.2s
#                    all        188        156      0.944      0.966       0.97      0.954
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      47/300      1.22G     0.3209     0.3633     0.8843         33        256: 100% ━━━━━━━━━━━━ 123/123 39.4it/s 3.1s0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 32.6it/s 0.2s.2s
#                    all        188        156       0.93      0.977      0.974      0.955
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      48/300      1.24G     0.3169     0.3578     0.8865         34        256: 100% ━━━━━━━━━━━━ 123/123 39.1it/s 3.1s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 32.6it/s 0.2s.2s
#                    all        188        156      0.954      0.965      0.973      0.957
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      49/300      1.25G      0.319     0.3652     0.8881         24        256: 100% ━━━━━━━━━━━━ 123/123 39.6it/s 3.1s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 30.6it/s 0.2s.2s
#                    all        188        156      0.955      0.965       0.98      0.961
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      50/300      1.27G     0.3079     0.3693      0.883         29        256: 100% ━━━━━━━━━━━━ 123/123 39.7it/s 3.1s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 32.4it/s 0.2s.2s
#                    all        188        156      0.923       0.97      0.966      0.951
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      51/300      1.29G     0.3194     0.3714     0.8874         33        256: 100% ━━━━━━━━━━━━ 123/123 39.4it/s 3.1s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 30.7it/s 0.2s.2s
#                    all        188        156      0.935      0.977       0.98      0.966
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      52/300      1.31G     0.3075     0.3566     0.8825         24        256: 100% ━━━━━━━━━━━━ 123/123 38.9it/s 3.2s0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 32.3it/s 0.2s.2s
#                    all        188        156      0.928      0.972      0.966      0.955
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      53/300      1.32G     0.3188     0.3482     0.8869         25        256: 100% ━━━━━━━━━━━━ 123/123 39.2it/s 3.1s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 32.3it/s 0.2s.2s
#                    all        188        156      0.952       0.98      0.969      0.956
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      54/300      1.34G     0.3075     0.3644     0.8855         25        256: 100% ━━━━━━━━━━━━ 123/123 39.3it/s 3.1s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 31.0it/s 0.2s.2s
#                    all        188        156      0.936      0.969      0.972      0.954
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      55/300      1.36G     0.3179     0.3582     0.8853         30        256: 100% ━━━━━━━━━━━━ 123/123 39.2it/s 3.1s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 32.0it/s 0.2s.2s
#                    all        188        156      0.934      0.956      0.974      0.967
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      56/300      1.38G     0.3131     0.3601     0.8875         22        256: 100% ━━━━━━━━━━━━ 123/123 38.8it/s 3.2s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 30.0it/s 0.2s.2s
#                    all        188        156      0.947      0.952      0.979      0.967
# EarlyStopping: Training stopped early as no improvement observed in last 20 epochs. Best results observed at epoch 36, best model saved as best.pt.
# To update EarlyStopping(patience=20) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 56 epochs completed in 0.053 hours.
# Optimizer stripped from /home/hector/Desktop/Puzzlebot-Challenge/training/runs/train3/weights/last.pt, 6.2MB
# Optimizer stripped from /home/hector/Desktop/Puzzlebot-Challenge/training/runs/train3/weights/best.pt, 6.2MB
#
# Validating /home/hector/Desktop/Puzzlebot-Challenge/training/runs/train3/weights/best.pt...
# Ultralytics 8.3.244 🚀 Python-3.10.12 torch-2.9.1+cu128 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 7806MiB)
# Model summary (fused): 72 layers, 3,007,403 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 13.7it/s 0.4s.3s
#                    all        188        156      0.953      0.981      0.976      0.968
#               Give-Way         21         21      0.999          1      0.995       0.97
#            Go-Straight         12         12          1       0.97      0.995      0.995
#            Green-Light         21         21      0.899          1      0.947       0.93
#              Red-Light         15         15      0.995          1      0.995      0.988
#                   Stop         29         29      0.997          1      0.995      0.995
#              Turn-Left         14         14      0.901      0.929      0.884      0.884
#             Turn-Right         12         12      0.854          1      0.989      0.989
#                Workers         15         15      0.935      0.933      0.985      0.973
#           Yellow-Light         17         17      0.997          1      0.995      0.991
# Speed: 0.0ms preprocess, 0.3ms inference, 0.0ms loss, 1.0ms postprocess per image
# Results saved to /home/hector/Desktop/Puzzlebot-Challenge/training/runs/train3

# %%
metrics = model.val()
print(metrics.box.map)     # mAP50-95
print(metrics.box.map50)   # mAP50
print(metrics.box.maps)    # per-class mAP50-95
