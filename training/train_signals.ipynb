# %% [markdown]
# # Train Traffic Sign YOLOv8 Model

# %%
import torch
from ultralytics import YOLO

print(f"torch={torch.__version__}  CUDA={torch.cuda.is_available()}")
# Out:
# torch=2.9.1+cu128  CUDA=True

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="NDhWAQO9NCJ3gOFQQ2s5")
project = rf.workspace("larc-hbgqy").project("traffic-signals-1t7zq")
version = project.version(4)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in Traffic-Signals-4 to yolov8:: 100%|██████████| 126498/126498 [00:05<00:00, 21165.38it/s]
# Extracting Dataset Version Zip to Traffic-Signals-4 in yolov8:: 100%|██████████| 2969/2969 [00:00<00:00, 10234.15it/s]

# %%
model = YOLO("yolov8n.pt")  

results = model.train(
    data="Traffic-Signals-4/data.yaml",
    epochs=300,
    imgsz=256,            
    batch=16,
    patience=20,
    fliplr=0.0,
    flipud=0.0,
    degrees=0.0,
    shear=0.0,
    project="runs",
    name="train",
)
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8n.pt to 'yolov8n.pt': 100% ━━━━━━━━━━━━ 6.2MB 14.5MB/s 0.4s.4s<0.0s2s
# New https://pypi.org/project/ultralytics/8.4.62 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.244 🚀 Python-3.10.12 torch-2.9.1+cu128 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 7806MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=Traffic-Signals-4/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=300, erasing=0.4, exist_ok=False, fliplr=0.0, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=256, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=20, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=runs, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/home/hector/Desktop/Puzzlebot-Challenge/training/runs/train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=6
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    752482  ultralytics.nn.modules.head.Detect           [6, [64, 128, 256]]
# Model summary: 129 layers, 3,012,018 parameters, 3,012,002 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt': 100% ━━━━━━━━━━━━ 5.4MB 14.5MB/s 0.4s.3s<0.1s2s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 5462.1±2959.6 MB/s, size: 96.8 KB)
# train: Scanning /home/hector/Desktop/Puzzlebot-Challenge/training/Traffic-Signals-4/train/labels... 1296 images, 300 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1296/1296 1.6Kit/s 0.8s0.1s
# train: New cache created: /home/hector/Desktop/Puzzlebot-Challenge/training/Traffic-Signals-4/train/labels.cache
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 993, len(boxes) = 996. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2245.8±1169.3 MB/s, size: 28.2 KB)
# val: Scanning /home/hector/Desktop/Puzzlebot-Challenge/training/Traffic-Signals-4/valid/labels... 124 images, 21 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 124/124 2.0Kit/s 0.1s
# val: New cache created: /home/hector/Desktop/Puzzlebot-Challenge/training/Traffic-Signals-4/valid/labels.cache
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 102, len(boxes) = 103. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# Plotting labels to /home/hector/Desktop/Puzzlebot-Challenge/training/runs/train/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 256 train, 256 val
# Using 8 dataloader workers
# Logging results to /home/hector/Desktop/Puzzlebot-Challenge/training/runs/train
# Starting training for 300 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/300     0.393G     0.6622      2.752      1.063         22        256: 100% ━━━━━━━━━━━━ 81/81 25.7it/s 3.1s0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 17.8it/s 0.2s.4s
#                    all        124        103      0.514      0.747      0.705      0.651
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/300     0.451G     0.6258      1.491      1.028         28        256: 100% ━━━━━━━━━━━━ 81/81 41.5it/s 2.0s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 30.8it/s 0.1s
#                    all        124        103      0.816      0.814      0.936       0.84
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/300     0.469G     0.6008      1.193      1.023         30        256: 100% ━━━━━━━━━━━━ 81/81 42.2it/s 1.9s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 29.4it/s 0.1s.1s
#                    all        124        103      0.875       0.79      0.909      0.831
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/300     0.486G     0.5738      1.067      1.001         24        256: 100% ━━━━━━━━━━━━ 81/81 42.7it/s 1.9s0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 30.6it/s 0.1s
#                    all        124        103      0.668      0.913      0.835      0.748
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/300     0.504G     0.5493     0.9835     0.9955         33        256: 100% ━━━━━━━━━━━━ 81/81 43.2it/s 1.9s0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 31.9it/s 0.1s
#                    all        124        103      0.931      0.904      0.955      0.898
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/300      0.52G     0.5331     0.9031     0.9913         24        256: 100% ━━━━━━━━━━━━ 81/81 43.5it/s 1.9s0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 31.8it/s 0.1s
#                    all        124        103      0.907      0.915      0.966      0.913
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/300     0.537G     0.4983     0.8619     0.9745         22        256: 100% ━━━━━━━━━━━━ 81/81 42.5it/s 1.9s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 31.5it/s 0.1s
#                    all        124        103      0.934      0.941      0.971      0.902
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/300     0.555G     0.5005     0.7944     0.9774         29        256: 100% ━━━━━━━━━━━━ 81/81 43.1it/s 1.9s0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 32.6it/s 0.1s
#                    all        124        103      0.967      0.889      0.966      0.909
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/300     0.572G     0.4634     0.7504     0.9577         31        256: 100% ━━━━━━━━━━━━ 81/81 43.5it/s 1.9s0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 32.5it/s 0.1s
#                    all        124        103      0.946      0.939      0.969      0.917
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/300     0.588G     0.4687     0.7126     0.9741         39        256: 100% ━━━━━━━━━━━━ 81/81 42.2it/s 1.9s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 30.3it/s 0.1s.1s
#                    all        124        103      0.928      0.952      0.969      0.929
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/300     0.605G     0.4463     0.7052     0.9613         25        256: 100% ━━━━━━━━━━━━ 81/81 41.9it/s 1.9s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 31.5it/s 0.1s
#                    all        124        103      0.932      0.971      0.966      0.926
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/300     0.623G     0.4524     0.6677     0.9614         24        256: 100% ━━━━━━━━━━━━ 81/81 41.4it/s 2.0s0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 32.7it/s 0.1s
#                    all        124        103      0.927      0.965      0.976      0.936
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/300     0.639G     0.4439     0.6529     0.9466         32        256: 100% ━━━━━━━━━━━━ 81/81 42.4it/s 1.9s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 32.3it/s 0.1s
#                    all        124        103      0.972      0.954      0.975      0.955
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/300     0.656G     0.4357     0.6431     0.9485         28        256: 100% ━━━━━━━━━━━━ 81/81 42.0it/s 1.9s0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 30.9it/s 0.1s
#                    all        124        103      0.957      0.945      0.975      0.944
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/300     0.674G      0.411     0.6264     0.9517         19        256: 100% ━━━━━━━━━━━━ 81/81 41.6it/s 1.9s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 32.0it/s 0.1s
#                    all        124        103      0.957      0.965      0.974      0.944
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/300     0.691G      0.408     0.5818     0.9415         24        256: 100% ━━━━━━━━━━━━ 81/81 41.2it/s 2.0s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 31.7it/s 0.1s
#                    all        124        103      0.934      0.951      0.973      0.944
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/300     0.707G     0.4056     0.5895     0.9443         25        256: 100% ━━━━━━━━━━━━ 81/81 41.1it/s 2.0s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 30.2it/s 0.1s.1s
#                    all        124        103      0.946      0.952       0.97      0.944
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/300     0.725G        0.4     0.5774     0.9415         28        256: 100% ━━━━━━━━━━━━ 81/81 40.8it/s 2.0s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 31.7it/s 0.1s
#                    all        124        103      0.872      0.916      0.957      0.897
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/300     0.742G      0.428     0.5601     0.9524         25        256: 100% ━━━━━━━━━━━━ 81/81 41.0it/s 2.0s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 31.3it/s 0.1s
#                    all        124        103      0.913       0.97      0.964      0.921
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/300      0.76G     0.3882     0.5314     0.9324         32        256: 100% ━━━━━━━━━━━━ 81/81 41.4it/s 2.0s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 32.1it/s 0.1s
#                    all        124        103      0.945      0.952      0.975      0.941
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/300     0.775G     0.3876     0.5344     0.9459         30        256: 100% ━━━━━━━━━━━━ 81/81 41.2it/s 2.0s0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 32.0it/s 0.1s
#                    all        124        103      0.872      0.963      0.959      0.924
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/300     0.793G     0.3775     0.5338     0.9383         25        256: 100% ━━━━━━━━━━━━ 81/81 41.2it/s 2.0s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 34.1it/s 0.1s
#                    all        124        103      0.936      0.944      0.972      0.946
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/300     0.811G     0.3782     0.5192     0.9368         22        256: 100% ━━━━━━━━━━━━ 81/81 40.6it/s 2.0s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 32.3it/s 0.1s
#                    all        124        103      0.937      0.925      0.957      0.931
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/300     0.826G     0.4021     0.5317     0.9478         24        256: 100% ━━━━━━━━━━━━ 81/81 41.5it/s 2.0s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 32.5it/s 0.1s
#                    all        124        103      0.912      0.959      0.965      0.937
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/300     0.844G     0.3849     0.5315     0.9393         26        256: 100% ━━━━━━━━━━━━ 81/81 40.8it/s 2.0s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 30.7it/s 0.1s
#                    all        124        103      0.939      0.971      0.977      0.943
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/300     0.861G      0.383      0.506      0.935         23        256: 100% ━━━━━━━━━━━━ 81/81 40.5it/s 2.0s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 33.6it/s 0.1s
#                    all        124        103      0.981      0.897      0.969       0.95
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/300     0.877G     0.3746     0.4933      0.938         12        256: 100% ━━━━━━━━━━━━ 81/81 41.2it/s 2.0s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 33.3it/s 0.1s
#                    all        124        103      0.931      0.936      0.977      0.948
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      28/300     0.895G     0.3621     0.4757      0.929         33        256: 100% ━━━━━━━━━━━━ 81/81 40.8it/s 2.0s0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 30.2it/s 0.1s.1s
#                    all        124        103      0.941      0.948      0.963      0.908
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      29/300     0.912G     0.3717     0.4745     0.9393         25        256: 100% ━━━━━━━━━━━━ 81/81 40.6it/s 2.0s0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 33.0it/s 0.1s
#                    all        124        103      0.924      0.961      0.972      0.944
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      30/300      0.93G     0.3703     0.5017     0.9404         37        256: 100% ━━━━━━━━━━━━ 81/81 40.5it/s 2.0s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 30.9it/s 0.1s.1s
#                    all        124        103      0.953      0.892       0.97      0.942
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      31/300     0.945G      0.359     0.4743     0.9362         25        256: 100% ━━━━━━━━━━━━ 81/81 40.5it/s 2.0s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 33.0it/s 0.1s
#                    all        124        103      0.925      0.969      0.976      0.946
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      32/300     0.963G     0.3506      0.441     0.9245         32        256: 100% ━━━━━━━━━━━━ 81/81 40.1it/s 2.0s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 31.0it/s 0.1s
#                    all        124        103      0.943      0.952      0.976      0.949
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      33/300      0.98G     0.3458     0.4591     0.9318         32        256: 100% ━━━━━━━━━━━━ 81/81 40.1it/s 2.0s0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 33.1it/s 0.1s
#                    all        124        103      0.935      0.955      0.977      0.957
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      34/300     0.998G     0.3475     0.4585     0.9288         26        256: 100% ━━━━━━━━━━━━ 81/81 39.4it/s 2.1s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 33.1it/s 0.1s
#                    all        124        103       0.95      0.961      0.979      0.957
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      35/300      1.01G     0.3429     0.4345     0.9247         24        256: 100% ━━━━━━━━━━━━ 81/81 39.7it/s 2.0s0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 33.7it/s 0.1s
#                    all        124        103      0.964      0.957      0.979      0.961
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      36/300      1.03G     0.3555      0.452     0.9296         25        256: 100% ━━━━━━━━━━━━ 81/81 39.8it/s 2.0s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 30.9it/s 0.1s
#                    all        124        103      0.971      0.946      0.978      0.962
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      37/300      1.05G      0.354     0.4406     0.9255         28        256: 100% ━━━━━━━━━━━━ 81/81 39.9it/s 2.0s0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 33.2it/s 0.1s
#                    all        124        103      0.958      0.959      0.974       0.95
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      38/300      1.07G     0.3342     0.4302     0.9246         21        256: 100% ━━━━━━━━━━━━ 81/81 39.7it/s 2.0s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 32.0it/s 0.1s
#                    all        124        103      0.927      0.974      0.979       0.96
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      39/300      1.08G     0.3421      0.445     0.9233         26        256: 100% ━━━━━━━━━━━━ 81/81 38.9it/s 2.1s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 30.0it/s 0.1s.1s
#                    all        124        103      0.904       0.98      0.968      0.945
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      40/300       1.1G     0.3425      0.443     0.9243         28        256: 100% ━━━━━━━━━━━━ 81/81 39.3it/s 2.1s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 32.5it/s 0.1s
#                    all        124        103      0.927      0.957      0.972      0.952
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      41/300      1.12G     0.3307     0.3981     0.9236         28        256: 100% ━━━━━━━━━━━━ 81/81 39.1it/s 2.1s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 33.1it/s 0.1s
#                    all        124        103      0.951      0.933      0.966      0.927
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      42/300      1.13G     0.3317     0.4049     0.9248         29        256: 100% ━━━━━━━━━━━━ 81/81 39.8it/s 2.0s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 33.9it/s 0.1s
#                    all        124        103      0.932      0.927      0.975      0.955
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      43/300      1.15G     0.3308     0.4211     0.9216         30        256: 100% ━━━━━━━━━━━━ 81/81 40.0it/s 2.0s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 31.1it/s 0.1s
#                    all        124        103      0.947      0.965      0.962      0.942
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      44/300      1.17G     0.3262     0.4299     0.9212         35        256: 100% ━━━━━━━━━━━━ 81/81 40.1it/s 2.0s0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 33.1it/s 0.1s
#                    all        124        103      0.957       0.96      0.979      0.953
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      45/300      1.18G     0.3306     0.4252     0.9241         24        256: 100% ━━━━━━━━━━━━ 81/81 40.4it/s 2.0s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 33.0it/s 0.1s
#                    all        124        103      0.906      0.967      0.967      0.949
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      46/300       1.2G     0.3309     0.3996     0.9173         28        256: 100% ━━━━━━━━━━━━ 81/81 40.1it/s 2.0s0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 30.8it/s 0.1s
#                    all        124        103      0.956      0.977      0.976      0.956
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      47/300      1.22G     0.3245     0.3942     0.9206         26        256: 100% ━━━━━━━━━━━━ 81/81 39.5it/s 2.1s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 30.2it/s 0.1s
#                    all        124        103      0.938      0.966      0.977      0.961
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      48/300      1.24G     0.3105     0.4127     0.9157         24        256: 100% ━━━━━━━━━━━━ 81/81 39.1it/s 2.1s0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 31.2it/s 0.1s
#                    all        124        103      0.962       0.96      0.978      0.951
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      49/300      1.25G     0.3184     0.4012     0.9179         33        256: 100% ━━━━━━━━━━━━ 81/81 40.7it/s 2.0s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 33.2it/s 0.1s
#                    all        124        103      0.928       0.97      0.977      0.952
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      50/300      1.27G     0.3153     0.4052     0.9169         34        256: 100% ━━━━━━━━━━━━ 81/81 40.1it/s 2.0s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 33.3it/s 0.1s
#                    all        124        103       0.92      0.972      0.975      0.955
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      51/300      1.29G     0.3206     0.3775     0.9124         24        256: 100% ━━━━━━━━━━━━ 81/81 40.9it/s 2.0s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 33.2it/s 0.1s
#                    all        124        103      0.934      0.963      0.975      0.953
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      52/300       1.3G     0.3092     0.3729     0.9144         26        256: 100% ━━━━━━━━━━━━ 81/81 39.7it/s 2.0s0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 33.9it/s 0.1s
#                    all        124        103      0.955      0.932      0.975      0.957
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      53/300      1.32G     0.3118     0.3671     0.9104         24        256: 100% ━━━━━━━━━━━━ 81/81 39.5it/s 2.0s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 33.3it/s 0.1s
#                    all        124        103      0.965      0.966       0.98      0.958
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      54/300      1.34G     0.3134     0.3829     0.9162         30        256: 100% ━━━━━━━━━━━━ 81/81 39.8it/s 2.0s0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 33.3it/s 0.1s
#                    all        124        103       0.94      0.964      0.978      0.959
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      55/300      1.36G     0.2931     0.3715     0.9018         28        256: 100% ━━━━━━━━━━━━ 81/81 41.0it/s 2.0s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 33.1it/s 0.1s
#                    all        124        103      0.961      0.947      0.975      0.964
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      56/300      1.37G     0.3021     0.3608      0.905         30        256: 100% ━━━━━━━━━━━━ 81/81 40.6it/s 2.0s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 33.7it/s 0.1s
#                    all        124        103      0.947      0.977      0.974      0.953
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      57/300      1.39G     0.2949     0.3636     0.9054         24        256: 100% ━━━━━━━━━━━━ 81/81 39.9it/s 2.0s0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 32.7it/s 0.1s
#                    all        124        103      0.952      0.948      0.978      0.968
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      58/300      1.41G     0.2975     0.3741     0.9066         24        256: 100% ━━━━━━━━━━━━ 81/81 40.4it/s 2.0s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 25.7it/s 0.2s.1s
#                    all        124        103      0.944      0.953      0.979      0.962
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      59/300      1.42G     0.3113     0.3744     0.9139         28        256: 100% ━━━━━━━━━━━━ 81/81 38.8it/s 2.1s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 31.3it/s 0.1s
#                    all        124        103      0.944       0.97      0.978       0.96
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      60/300      1.44G     0.2945     0.3599     0.9117         29        256: 100% ━━━━━━━━━━━━ 81/81 40.1it/s 2.0s0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 29.7it/s 0.1s.1s
#                    all        124        103      0.938      0.952       0.97      0.956
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      61/300      1.46G     0.3111     0.3687     0.9114         27        256: 100% ━━━━━━━━━━━━ 81/81 39.4it/s 2.1s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 28.6it/s 0.1s.1s
#                    all        124        103      0.888      0.975      0.956      0.941
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      62/300      1.47G     0.2873     0.3541     0.9024         31        256: 100% ━━━━━━━━━━━━ 81/81 38.8it/s 2.1s0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 29.6it/s 0.1s.1s
#                    all        124        103      0.949      0.966      0.977      0.959
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      63/300      1.49G     0.3012     0.3698     0.9141         23        256: 100% ━━━━━━━━━━━━ 81/81 39.1it/s 2.1s0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 31.7it/s 0.1s
#                    all        124        103      0.932      0.967      0.972      0.963
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      64/300      1.51G     0.2929     0.3561     0.9093         36        256: 100% ━━━━━━━━━━━━ 81/81 39.3it/s 2.1s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 29.5it/s 0.1s.1s
#                    all        124        103      0.956      0.977      0.977      0.953
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      65/300      1.53G     0.3046     0.3591     0.9062         30        256: 100% ━━━━━━━━━━━━ 81/81 39.8it/s 2.0s0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 29.2it/s 0.1s.1s
#                    all        124        103      0.943       0.95      0.967      0.955
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      66/300      1.54G     0.2976     0.3512     0.9037         29        256: 100% ━━━━━━━━━━━━ 81/81 39.3it/s 2.1s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 29.9it/s 0.1s
#                    all        124        103       0.96      0.962      0.975       0.96
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      67/300      1.56G     0.2848     0.3454     0.9042         28        256: 100% ━━━━━━━━━━━━ 81/81 39.5it/s 2.1s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 28.5it/s 0.1s.1s
#                    all        124        103      0.935      0.977      0.972      0.954
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      68/300      1.58G     0.2883     0.3408     0.9058         24        256: 100% ━━━━━━━━━━━━ 81/81 39.0it/s 2.1s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 30.0it/s 0.1s.1s
#                    all        124        103      0.958      0.969       0.97      0.954
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      69/300      1.59G     0.2931     0.3623     0.9116         29        256: 100% ━━━━━━━━━━━━ 81/81 38.7it/s 2.1s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 31.4it/s 0.1s
#                    all        124        103      0.936       0.96      0.964      0.942
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      70/300      1.61G     0.2948     0.3505     0.9103         29        256: 100% ━━━━━━━━━━━━ 81/81 38.4it/s 2.1s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 32.6it/s 0.1s
#                    all        124        103      0.953      0.942       0.98      0.962
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      71/300      1.63G      0.289     0.3663     0.9002         35        256: 100% ━━━━━━━━━━━━ 81/81 38.3it/s 2.1s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 31.4it/s 0.1s
#                    all        124        103      0.939      0.977      0.981      0.964
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      72/300      1.64G     0.2826     0.3444     0.9046         26        256: 100% ━━━━━━━━━━━━ 81/81 38.3it/s 2.1s0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 29.1it/s 0.1s.1s
#                    all        124        103      0.928      0.968      0.978       0.96
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      73/300      1.66G     0.2825     0.3449     0.9007         33        256: 100% ━━━━━━━━━━━━ 81/81 38.6it/s 2.1s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 30.7it/s 0.1s
#                    all        124        103      0.945      0.977      0.977      0.965
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      74/300      1.68G     0.2765     0.3272     0.8958         30        256: 100% ━━━━━━━━━━━━ 81/81 38.6it/s 2.1s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 31.4it/s 0.1s
#                    all        124        103      0.937      0.972      0.962      0.949
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      75/300       1.7G     0.2894     0.3517     0.9053         27        256: 100% ━━━━━━━━━━━━ 81/81 39.9it/s 2.0s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 32.2it/s 0.1s
#                    all        124        103      0.941      0.976       0.98      0.952
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      76/300      1.71G     0.2873     0.3337     0.9027         30        256: 100% ━━━━━━━━━━━━ 81/81 39.3it/s 2.1s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 29.3it/s 0.1s.1s
#                    all        124        103      0.943      0.974      0.977      0.946
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      77/300      1.73G     0.2865     0.3379     0.9119         24        256: 100% ━━━━━━━━━━━━ 81/81 39.7it/s 2.0s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 28.6it/s 0.1s.1s
#                    all        124        103      0.948      0.964       0.98      0.952
# EarlyStopping: Training stopped early as no improvement observed in last 20 epochs. Best results observed at epoch 57, best model saved as best.pt.
# To update EarlyStopping(patience=20) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 77 epochs completed in 0.049 hours.
# Optimizer stripped from /home/hector/Desktop/Puzzlebot-Challenge/training/runs/train/weights/last.pt, 6.2MB
# Optimizer stripped from /home/hector/Desktop/Puzzlebot-Challenge/training/runs/train/weights/best.pt, 6.2MB
#
# Validating /home/hector/Desktop/Puzzlebot-Challenge/training/runs/train/weights/best.pt...
# Ultralytics 8.3.244 🚀 Python-3.10.12 torch-2.9.1+cu128 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 7806MiB)
# Model summary (fused): 72 layers, 3,006,818 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.8it/s 0.4s.2s
#                    all        124        103      0.952      0.948      0.978      0.968
#               Give-Way         21         21      0.994          1      0.995      0.974
#            Go-Straight         12         12          1      0.827      0.995      0.995
#                   Stop         29         29      0.997          1      0.995      0.995
#              Turn-Left         14         14      0.923      0.929      0.926       0.92
#             Turn-Right         12         12      0.873          1      0.976      0.976
#                Workers         15         15      0.922      0.933      0.982      0.947
# Speed: 0.0ms preprocess, 0.2ms inference, 0.0ms loss, 0.3ms postprocess per image
# Results saved to /home/hector/Desktop/Puzzlebot-Challenge/training/runs/train

# %%
metrics = model.val()
print(metrics.box.map)     # mAP50-95
print(metrics.box.map50)   # mAP50
print(metrics.box.maps)    # per-class mAP50-95
