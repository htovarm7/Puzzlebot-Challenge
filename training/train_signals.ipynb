# %% [markdown]
# # Train Traffic Sign YOLOv8 Model

# %%
# !pip install roboflow
import torch
from ultralytics import YOLO

print(f"torch={torch.__version__}  CUDA={torch.cuda.is_available()}")

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="NDhWAQO9NCJ3gOFQQ2s5")
project = rf.workspace("larc-hbgqy").project("traffic-signals-1t7zq")
version = project.version(3)
dataset = version.download("yolov8")
# Out:
# The 'strict' parameter is no longer needed on Python 3+. This will raise an error in urllib3 v3.0.
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Traffic-Signals-3 in yolov8:: 100%|██████████| 2413/2413 [00:00<00:00, 17969.12it/s]

# %%
model = YOLO("yolov8n.pt")  

results = model.train(
    data="Traffic-Signals-3/data.yaml",
    epochs=200,
    imgsz=256,            
    batch=16,
    patience=20,
    fliplr=0.0,
    flipud=0.0,
    degrees=0.0,
    shear=0.0,
    project="runs",
    name="train",
)
# Out:
# New https://pypi.org/project/ultralytics/8.4.61 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.10 🚀 Python-3.10.12 torch-2.10.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3060, 11901MiB)
# ...

# %%
metrics = model.val()
print(metrics.box.map)     # mAP50-95
print(metrics.box.map50)   # mAP50
print(metrics.box.maps)    # per-class mAP50-95
